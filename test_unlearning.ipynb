# %% [markdown]
# <a href="https://colab.research.google.com/github/tungduong03/Deep-Learning/blob/main/test_unlearning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()  # Chọn file .zip dự án của bạn
# Out:
#      <input type="file" id="files-ccaa5898-f618-46ac-9e62-1e53cf81ab46" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ccaa5898-f618-46ac-9e62-1e53cf81ab46">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !unzip /content/LifeLongAnomalyUnlearn-main.zip -d /content/LifeLongAnomalyUnlearn  # Ví dụ: !unzip project.zip -d /content/project
# Out:
# Archive:  /content/LifeLongAnomalyUnlearn-main.zip
#    creating: /content/LifeLongAnomalyUnlearn/LifeLongAnomalyUnlearn-main/
#   inflating: /content/LifeLongAnomalyUnlearn/LifeLongAnomalyUnlearn-main/.gitignore
#    creating: /content/LifeLongAnomalyUnlearn/LifeLongAnomalyUnlearn-main/continual/
#    creating: /content/LifeLongAnomalyUnlearn/LifeLongAnomalyUnlearn-main/data/
#   inflating: /content/LifeLongAnomalyUnlearn/LifeLongAnomalyUnlearn-main/data/dataset.py
#   inflating: /content/LifeLongAnomalyUnlearn/LifeLongAnomalyUnlearn-main/data/parser.py
#   inflating: /content/LifeLongAnomalyUnlearn/LifeLongAnomalyUnlearn-main/data/processor.py
#   inflating: /content/LifeLongAnomalyUnlearn/LifeLongAnomalyUnlearn-main/data/vocab.py
#    creating: /content/LifeLongAnomalyUnlearn/LifeLongAnomalyUnlearn-main/data/__pycache__/
#   inflating: /content/LifeLongAnomalyUnlearn/LifeLongAnomalyUnlearn-main/data/__pycache__/dataset.cpython-310.pyc
# ...

# %%
# !unzip /content/LifeLongAnomalyUnlearn/LifeLongAnomalyUnlearn-main/preprocessed.zip -d /content/LifeLongAnomalyUnlearn/LifeLongAnomalyUnlearn-main  # Ví dụ: !unzip project.zip -d /content/project
# Out:
# Archive:  /content/LifeLongAnomalyUnlearn/LifeLongAnomalyUnlearn-main/preprocessed.zip
#   inflating: /content/LifeLongAnomalyUnlearn/LifeLongAnomalyUnlearn-main/preprocessed/anomaly_label.csv
#   inflating: /content/LifeLongAnomalyUnlearn/LifeLongAnomalyUnlearn-main/preprocessed/Event_occurrence_matrix.csv
#   inflating: /content/LifeLongAnomalyUnlearn/LifeLongAnomalyUnlearn-main/preprocessed/Event_traces.csv
#   inflating: /content/LifeLongAnomalyUnlearn/LifeLongAnomalyUnlearn-main/preprocessed/HDFS.log_templates.csv
#   inflating: /content/LifeLongAnomalyUnlearn/LifeLongAnomalyUnlearn-main/preprocessed/HDFS.npz

# %%
# %cd /content/LifeLongAnomalyUnlearn/LifeLongAnomalyUnlearn-main
# Out:
# /content/LifeLongAnomalyUnlearn/LifeLongAnomalyUnlearn-main

# %%
# !pip install -r requirements.txt
# Out:
# ...
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProtocolError('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))': /simple/joblib/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 383.1/383.1 kB 7.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.9/58.9 kB 3.8 MB/s eta 0:00:00
# ...

# %%
# !pip install torch logparser3

# %%
# !python main.py
# Out:
# 1
# Parsing file: /content/LifeLongAnomalyUnlearn/LifeLongAnomalyUnlearn-main/HDFS.log
# Total lines:  1496929
# Processed 0.1% of log lines.
# Processed 0.1% of log lines.
# Processed 0.2% of log lines.
# Processed 0.3% of log lines.
# Processed 0.3% of log lines.
# Processed 0.4% of log lines.
# Processed 0.5% of log lines.
# Processed 0.5% of log lines.
# Processed 0.6% of log lines.
# Processed 0.7% of log lines.
# Processed 0.7% of log lines.
# Processed 0.8% of log lines.
# Processed 0.9% of log lines.
# Processed 0.9% of log lines.
# Processed 1.0% of log lines.
# Processed 1.1% of log lines.
# Processed 1.1% of log lines.
# Processed 1.2% of log lines.
# Processed 1.3% of log lines.
# Processed 1.3% of log lines.
# Processed 1.4% of log lines.
# Processed 1.5% of log lines.
# Processed 1.5% of log lines.
# Processed 1.6% of log lines.
# Processed 1.7% of log lines.
# Processed 1.7% of log lines.
# Processed 1.8% of log lines.
# Processed 1.9% of log lines.
# ...
